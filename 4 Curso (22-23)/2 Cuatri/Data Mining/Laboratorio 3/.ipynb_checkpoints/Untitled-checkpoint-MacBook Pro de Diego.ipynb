# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, confusion_matrix



# Cargar el dataset
df = pd.read_csv("RecursosLab3/olimpiadas.csv")

le = LabelEncoder()
df['Sex'] = le.fit_transform(df['Sex'])
df.dropna()


X = df[['Sex', 'Age', 'Height', 'Weight']]
y = df['Medal']

df
# Out:
#             ID                      Name  Sex   Age  Height  Weight  \
# 0            1                 A Dijiang    1  24.0   180.0    80.0
# 1            2                  A Lamusi    1  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby    1  24.0     NaN     NaN
# 3            4      Edgar Lindenau Aabye    1  34.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink    0  21.0   185.0    82.0
# ...        ...                       ...  ...   ...     ...     ...
# 271111  135569                Andrzej ya    1  29.0   179.0    89.0
# 271112  135570                  Piotr ya    1  27.0   176.0    59.0
# 271113  135570                  Piotr ya    1  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya    1  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya    1  34.0   185.0    96.0
#
#                   Team  NOC        Games  Year  Season            City  \
# 0                China  CHN  1992 Summer  1992  Summer       Barcelona
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/t8/n5_055wn3xj7gs9j0kmw7kkr0000gn/T/ipykernel_74376/306479669.py in <module>
#       1 scaler = StandardScaler()
# ----> 2 X_train = scaler.fit_transform(X_train)
#       3 X_test = scaler.transform(X_test)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py in fit_transform(self, X, y, **fit_params)
#     850         if y is None:
#     851             # fit method of arity 1 (unsupervised transformation)
# --> 852             return self.fit(X, **fit_params).transform(X)
#     853         else:
#     854             # fit method of arity 2 (supervised transformation)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_data.py in fit(self, X, y, sample_weight)
#     804         # Reset internal state before fitting
#     805         self._reset()
# ...

# %%
clf = KNeighborsClassifier(n_neighbors=5, metric='euclidean')
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)

# %%
n_neighbors = [3, 5, 7, 9]
metrics = ['euclidean', 'manhattan', 'chebyshev']

results = []
for k in n_neighbors:
    for m in metrics:
        clf = KNeighborsClassifier(n_neighbors=k, metric=m)
        clf.fit(X_train, y_train)
        y_pred = clf.predict(X_test)
        acc = accuracy_score(y_test, y_pred)
        cm = confusion_matrix(y_test, y_pred)
        results.append((k, m, acc, cm))

df_results = pd.DataFrame(results, columns=['n_neighbors', 'metric', 'accuracy', 'confusion_matrix'])

# %%
# Definir los datos de los atletas a predecir
bruno = np.array([1, 27, 1.83, 78]) # Sexo, Edad, Altura, Peso
carolina = np.array([0, 27, 1.73, 66])
baloncesto = np.array([0, 28, 1.85, 72])

# Normalizar los datos
atletas = np.vstack((bruno, carolina, baloncesto))
atletas_norm = (atletas - X_mean) / X_std

# %%
# Predecir las medallas de los atletas utilizando el modelo de clasificación
medallas_pred = knn.predict(atletas_norm)

# Imprimir las medallas predichas para cada atleta
print('Bruno Hortelano: {}'.format(medallas_pred[0]))
print('Carolina Marín: {}'.format(medallas_pred[1]))
print('Selección femenina de baloncesto: {}'.format(medallas_pred[2]))
