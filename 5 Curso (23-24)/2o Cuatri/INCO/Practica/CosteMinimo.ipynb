# %% [markdown]
# # Algoritmo Coste Minimo
# Alumnos:
# *   Diego Viñals Lage
# *   Javier Garrido Cobo
# *   Alejandro Quiroz Coscollano
# *   Daniel Ojeda Velasco
# *   Pablo Quétin de la Vega
# *   Ignacio Tejero Ruiz

# %%
import heapq

def es_valido(sudoku, fila, col, num):
    # Esta función verifica si es posible colocar el número 'num' en la posición especificada (fila, col).
    # Se asegura que el número no esté ya en la misma fila o columna.
    for i in range(9):
        if sudoku[fila][i] == num or sudoku[i][col] == num:
            return False

    # También verifica el cuadrante 3x3 para asegurar que 'num' no esté presente.
    inicio_fila = fila - fila % 3
    inicio_col = col - col % 3
    for i in range(3):
        for j in range(3):
            if sudoku[inicio_fila + i][inicio_col + j] == num:
                return False

    return True

def resolver_sudoku_costo_minimo(sudoku):
    pq = []  # Se utiliza una cola de prioridad para gestionar los estados del Sudoku por su costo.
    heapq.heappush(pq, (0, sudoku, []))  # Se agrega el estado inicial con un costo de 0.

    while pq:
        costo, current, moves = heapq.heappop(pq)  # Se extrae el estado con el menor costo.

        vacia = encontrar_vacia(current)
        if not vacia:  # Si no hay celdas vacías, el sudoku está resuelto.
            print("\nCoste total de la solución: ", costo)
            print("Sudoku Resuelto:")
            imprimir_sudoku(current)
            return True

        fila, col = vacia
        for num in range(1, 10):
            if es_valido(current, fila, col, num):
                next_state = [row[:] for row in current]  # Crea una nueva instancia del estado con el número colocado.
                next_state[fila][col] = num
                nuevo_costo = costo + 1  # Incrementa el costo por cada movimiento.
                print(f"Intentar asignar {num} en ({fila}, {col}) con costo {nuevo_costo}")
                heapq.heappush(pq, (nuevo_costo, next_state, moves + [(num, (fila, col), nuevo_costo)]))

    print("No se encontró solución.")
    return False

def encontrar_vacia(sudoku):
    # Esta función busca una celda vacía en el sudoku (representada por un 0).
    for i in range(9):
        for j in range(9):
            if sudoku[i][j] == 0:
                return (i, j)
    return None

def imprimir_sudoku(sudoku):
    # Imprime el estado actual del sudoku de manera legible.
    for row in sudoku:
        print(" ".join(str(num) if num != 0 else '.' for num in row))
    print("\n" + "-" * 21 + "\n")

# Sudoku inicial para probar el algoritmo
sudoku = [
    [5, 3, 0, 0, 7, 0, 0, 0, 0],
    [6, 0, 0, 1, 9, 5, 0, 0, 0],
    [0, 9, 8, 0, 0, 0, 0, 6, 0],
    [8, 0, 0, 0, 6, 0, 0, 0, 3],
    [4, 0, 0, 8, 0, 3, 0, 0, 1],
    [7, 0, 0, 0, 2, 0, 0, 0, 6],
    [0, 6, 0, 0, 0, 0, 2, 8, 0],
    [0, 0, 0, 4, 1, 9, 0, 0, 5],
    [0, 0, 0, 0, 8, 0, 0, 7, 9]
]

if not resolver_sudoku_costo_minimo(sudoku):
    print("No se encontró solución")
# Out:
# Intentar asignar 1 en (0, 2) con costo 1
# Intentar asignar 2 en (0, 2) con costo 1
# Intentar asignar 4 en (0, 2) con costo 1
# Intentar asignar 2 en (0, 3) con costo 2
# Intentar asignar 6 en (0, 3) con costo 2
# Intentar asignar 6 en (0, 3) con costo 2
# Intentar asignar 2 en (0, 3) con costo 2
# Intentar asignar 6 en (0, 3) con costo 2
# Intentar asignar 4 en (0, 5) con costo 3
# Intentar asignar 6 en (0, 5) con costo 3
# Intentar asignar 8 en (0, 5) con costo 3
# Intentar asignar 2 en (0, 5) con costo 3
# Intentar asignar 4 en (0, 5) con costo 3
# Intentar asignar 8 en (0, 5) con costo 3
# Intentar asignar 4 en (0, 5) con costo 3
# Intentar asignar 8 en (0, 5) con costo 3
# Intentar asignar 6 en (0, 5) con costo 3
# Intentar asignar 8 en (0, 5) con costo 3
# Intentar asignar 2 en (0, 5) con costo 3
# Intentar asignar 8 en (0, 5) con costo 3
# Intentar asignar 8 en (0, 6) con costo 4
# Intentar asignar 9 en (0, 6) con costo 4
# Intentar asignar 4 en (0, 6) con costo 4
# Intentar asignar 8 en (0, 6) con costo 4
# Intentar asignar 9 en (0, 6) con costo 4
# Intentar asignar 4 en (0, 6) con costo 4
# Intentar asignar 9 en (0, 6) con costo 4
# Intentar asignar 4 en (0, 6) con costo 4
# Intentar asignar 8 en (0, 6) con costo 4
# Intentar asignar 9 en (0, 6) con costo 4
# Intentar asignar 8 en (0, 6) con costo 4
# Intentar asignar 9 en (0, 6) con costo 4
# Intentar asignar 4 en (0, 6) con costo 4
# Intentar asignar 9 en (0, 6) con costo 4
# Intentar asignar 1 en (0, 6) con costo 4
# Intentar asignar 8 en (0, 6) con costo 4
# Intentar asignar 9 en (0, 6) con costo 4
# Intentar asignar 1 en (0, 6) con costo 4
# Intentar asignar 4 en (0, 6) con costo 4
# Intentar asignar 9 en (0, 6) con costo 4
# Intentar asignar 1 en (0, 6) con costo 4
# Intentar asignar 8 en (0, 6) con costo 4
# Intentar asignar 9 en (0, 6) con costo 4
# Intentar asignar 1 en (0, 6) con costo 4
# Intentar asignar 9 en (0, 6) con costo 4
# Intentar asignar 1 en (0, 6) con costo 4
# Intentar asignar 8 en (0, 6) con costo 4
# Intentar asignar 9 en (0, 6) con costo 4
# Intentar asignar 1 en (0, 6) con costo 4
# Intentar asignar 9 en (0, 6) con costo 4
# Intentar asignar 9 en (0, 7) con costo 5
# Intentar asignar 9 en (0, 7) con costo 5
# Intentar asignar 4 en (0, 7) con costo 5
# Intentar asignar 9 en (0, 7) con costo 5
# Intentar asignar 4 en (0, 7) con costo 5
# Intentar asignar 9 en (0, 7) con costo 5
# Intentar asignar 4 en (0, 7) con costo 5
# Intentar asignar 9 en (0, 7) con costo 5
# Intentar asignar 4 en (0, 7) con costo 5
# Intentar asignar 9 en (0, 7) con costo 5
# Intentar asignar 4 en (0, 7) con costo 5
# Intentar asignar 2 en (0, 7) con costo 5
# Intentar asignar 9 en (0, 7) con costo 5
# Intentar asignar 2 en (0, 7) con costo 5
# Intentar asignar 2 en (0, 7) con costo 5
# Intentar asignar 9 en (0, 7) con costo 5
# Intentar asignar 2 en (0, 7) con costo 5
# Intentar asignar 4 en (0, 7) con costo 5
# Intentar asignar 9 en (0, 7) con costo 5
# Intentar asignar 1 en (0, 7) con costo 5
# Intentar asignar 9 en (0, 7) con costo 5
# Intentar asignar 1 en (0, 7) con costo 5
# Intentar asignar 4 en (0, 7) con costo 5
# Intentar asignar 9 en (0, 7) con costo 5
# Intentar asignar 1 en (0, 7) con costo 5
# Intentar asignar 9 en (0, 7) con costo 5
# Intentar asignar 1 en (0, 7) con costo 5
# Intentar asignar 4 en (0, 7) con costo 5
# Intentar asignar 9 en (0, 7) con costo 5
# Intentar asignar 1 en (0, 7) con costo 5
# Intentar asignar 9 en (0, 7) con costo 5
# Intentar asignar 1 en (0, 7) con costo 5
# Intentar asignar 9 en (0, 7) con costo 5
# Intentar asignar 1 en (0, 7) con costo 5
# Intentar asignar 9 en (0, 7) con costo 5
# Intentar asignar 1 en (0, 7) con costo 5
# Intentar asignar 9 en (0, 7) con costo 5
# Intentar asignar 1 en (0, 7) con costo 5
# Intentar asignar 2 en (0, 7) con costo 5
# Intentar asignar 9 en (0, 7) con costo 5
# Intentar asignar 1 en (0, 7) con costo 5
# Intentar asignar 2 en (0, 7) con costo 5
# Intentar asignar 8 en (0, 8) con costo 6
# Intentar asignar 4 en (0, 8) con costo 6
# Intentar asignar 8 en (0, 8) con costo 6
# Intentar asignar 8 en (0, 8) con costo 6
# Intentar asignar 4 en (0, 8) con costo 6
# Intentar asignar 8 en (0, 8) con costo 6
# Intentar asignar 2 en (0, 8) con costo 6
# Intentar asignar 8 en (0, 8) con costo 6
# Intentar asignar 2 en (0, 8) con costo 6
# Intentar asignar 4 en (0, 8) con costo 6
# Intentar asignar 2 en (0, 8) con costo 6
# Intentar asignar 8 en (0, 8) con costo 6
# Intentar asignar 8 en (0, 8) con costo 6
# Intentar asignar 4 en (0, 8) con costo 6
# Intentar asignar 4 en (0, 8) con costo 6
# Intentar asignar 8 en (0, 8) con costo 6
# Intentar asignar 8 en (0, 8) con costo 6
# Intentar asignar 8 en (0, 8) con costo 6
# Intentar asignar 8 en (0, 8) con costo 6
# Intentar asignar 2 en (0, 8) con costo 6
# Intentar asignar 2 en (0, 8) con costo 6
# Intentar asignar 2 en (1, 1) con costo 7
# Intentar asignar 4 en (1, 1) con costo 7
# Intentar asignar 7 en (1, 1) con costo 7
# Intentar asignar 2 en (1, 1) con costo 7
# Intentar asignar 4 en (1, 1) con costo 7
# Intentar asignar 7 en (1, 1) con costo 7
# Intentar asignar 2 en (1, 1) con costo 7
# Intentar asignar 4 en (1, 1) con costo 7
# Intentar asignar 7 en (1, 1) con costo 7
# Intentar asignar 2 en (1, 1) con costo 7
# Intentar asignar 4 en (1, 1) con costo 7
# Intentar asignar 7 en (1, 1) con costo 7
# Intentar asignar 2 en (1, 1) con costo 7
# Intentar asignar 4 en (1, 1) con costo 7
# Intentar asignar 7 en (1, 1) con costo 7
# Intentar asignar 2 en (1, 1) con costo 7
# Intentar asignar 4 en (1, 1) con costo 7
# Intentar asignar 7 en (1, 1) con costo 7
# Intentar asignar 2 en (1, 1) con costo 7
# Intentar asignar 4 en (1, 1) con costo 7
# Intentar asignar 7 en (1, 1) con costo 7
# Intentar asignar 2 en (1, 1) con costo 7
# Intentar asignar 4 en (1, 1) con costo 7
# Intentar asignar 7 en (1, 1) con costo 7
# Intentar asignar 2 en (1, 1) con costo 7
# Intentar asignar 4 en (1, 1) con costo 7
# Intentar asignar 7 en (1, 1) con costo 7
# Intentar asignar 2 en (1, 1) con costo 7
# Intentar asignar 4 en (1, 1) con costo 7
# Intentar asignar 7 en (1, 1) con costo 7
# Intentar asignar 2 en (1, 1) con costo 7
# Intentar asignar 4 en (1, 1) con costo 7
# Intentar asignar 7 en (1, 1) con costo 7
# Intentar asignar 4 en (1, 1) con costo 7
# Intentar asignar 7 en (1, 1) con costo 7
# Intentar asignar 4 en (1, 1) con costo 7
# Intentar asignar 7 en (1, 1) con costo 7
# Intentar asignar 4 en (1, 1) con costo 7
# Intentar asignar 7 en (1, 1) con costo 7
# Intentar asignar 4 en (1, 1) con costo 7
# Intentar asignar 7 en (1, 1) con costo 7
# Intentar asignar 2 en (1, 1) con costo 7
# Intentar asignar 7 en (1, 1) con costo 7
# Intentar asignar 2 en (1, 1) con costo 7
# Intentar asignar 7 en (1, 1) con costo 7
# Intentar asignar 2 en (1, 1) con costo 7
# Intentar asignar 7 en (1, 1) con costo 7
# Intentar asignar 2 en (1, 1) con costo 7
# Intentar asignar 7 en (1, 1) con costo 7
# Intentar asignar 2 en (1, 1) con costo 7
# Intentar asignar 7 en (1, 1) con costo 7
# Intentar asignar 2 en (1, 1) con costo 7
# Intentar asignar 7 en (1, 1) con costo 7
# Intentar asignar 4 en (1, 2) con costo 8
# Intentar asignar 7 en (1, 2) con costo 8
# Intentar asignar 2 en (1, 2) con costo 8
# Intentar asignar 7 en (1, 2) con costo 8
# Intentar asignar 2 en (1, 2) con costo 8
# Intentar asignar 4 en (1, 2) con costo 8
# Intentar asignar 4 en (1, 2) con costo 8
# Intentar asignar 7 en (1, 2) con costo 8
# Intentar asignar 2 en (1, 2) con costo 8
# Intentar asignar 7 en (1, 2) con costo 8
# Intentar asignar 2 en (1, 2) con costo 8
# Intentar asignar 4 en (1, 2) con costo 8
# Intentar asignar 4 en (1, 2) con costo 8
# Intentar asignar 7 en (1, 2) con costo 8
# Intentar asignar 2 en (1, 2) con costo 8
# Intentar asignar 7 en (1, 2) con costo 8
# Intentar asignar 2 en (1, 2) con costo 8
# Intentar asignar 4 en (1, 2) con costo 8
# Intentar asignar 4 en (1, 2) con costo 8
# Intentar asignar 7 en (1, 2) con costo 8
# Intentar asignar 2 en (1, 2) con costo 8
# Intentar asignar 7 en (1, 2) con costo 8
# Intentar asignar 2 en (1, 2) con costo 8
# Intentar asignar 4 en (1, 2) con costo 8
# Intentar asignar 4 en (1, 2) con costo 8
# Intentar asignar 7 en (1, 2) con costo 8
# Intentar asignar 2 en (1, 2) con costo 8
# Intentar asignar 7 en (1, 2) con costo 8
# Intentar asignar 2 en (1, 2) con costo 8
# Intentar asignar 4 en (1, 2) con costo 8
# Intentar asignar 4 en (1, 2) con costo 8
# Intentar asignar 7 en (1, 2) con costo 8
# Intentar asignar 2 en (1, 2) con costo 8
# Intentar asignar 7 en (1, 2) con costo 8
# Intentar asignar 2 en (1, 2) con costo 8
# Intentar asignar 4 en (1, 2) con costo 8
# Intentar asignar 4 en (1, 2) con costo 8
# Intentar asignar 7 en (1, 2) con costo 8
# Intentar asignar 2 en (1, 2) con costo 8
# Intentar asignar 7 en (1, 2) con costo 8
# Intentar asignar 2 en (1, 2) con costo 8
# Intentar asignar 4 en (1, 2) con costo 8
# Intentar asignar 4 en (1, 2) con costo 8
# Intentar asignar 7 en (1, 2) con costo 8
# Intentar asignar 2 en (1, 2) con costo 8
# Intentar asignar 7 en (1, 2) con costo 8
# Intentar asignar 2 en (1, 2) con costo 8
# Intentar asignar 4 en (1, 2) con costo 8
# Intentar asignar 4 en (1, 2) con costo 8
# Intentar asignar 7 en (1, 2) con costo 8
# Intentar asignar 2 en (1, 2) con costo 8
# Intentar asignar 7 en (1, 2) con costo 8
# Intentar asignar 2 en (1, 2) con costo 8
# Intentar asignar 4 en (1, 2) con costo 8
# Intentar asignar 4 en (1, 2) con costo 8
# Intentar asignar 7 en (1, 2) con costo 8
# Intentar asignar 2 en (1, 2) con costo 8
# Intentar asignar 7 en (1, 2) con costo 8
# Intentar asignar 2 en (1, 2) con costo 8
# Intentar asignar 4 en (1, 2) con costo 8
# Intentar asignar 4 en (1, 2) con costo 8
# Intentar asignar 7 en (1, 2) con costo 8
# Intentar asignar 2 en (1, 2) con costo 8
# Intentar asignar 7 en (1, 2) con costo 8
# Intentar asignar 2 en (1, 2) con costo 8
# Intentar asignar 4 en (1, 2) con costo 8
# Intentar asignar 7 en (1, 2) con costo 8
# Intentar asignar 4 en (1, 2) con costo 8
# Intentar asignar 7 en (1, 2) con costo 8
# Intentar asignar 4 en (1, 2) con costo 8
# Intentar asignar 7 en (1, 2) con costo 8
# Intentar asignar 4 en (1, 2) con costo 8
# Intentar asignar 7 en (1, 2) con costo 8
# Intentar asignar 4 en (1, 2) con costo 8
# Intentar asignar 7 en (1, 2) con costo 8
# Intentar asignar 2 en (1, 2) con costo 8
# Intentar asignar 7 en (1, 2) con costo 8
# Intentar asignar 2 en (1, 2) con costo 8
# Intentar asignar 7 en (1, 2) con costo 8
# Intentar asignar 2 en (1, 2) con costo 8
# Intentar asignar 7 en (1, 2) con costo 8
# Intentar asignar 2 en (1, 2) con costo 8
# Intentar asignar 7 en (1, 2) con costo 8
# Intentar asignar 2 en (1, 2) con costo 8
# Intentar asignar 7 en (1, 2) con costo 8
# Intentar asignar 2 en (1, 2) con costo 8
# Intentar asignar 3 en (1, 6) con costo 9
# Intentar asignar 7 en (1, 6) con costo 9
# Intentar asignar 3 en (1, 6) con costo 9
# Intentar asignar 3 en (1, 6) con costo 9
# Intentar asignar 7 en (1, 6) con costo 9
# Intentar asignar 3 en (1, 6) con costo 9
# Intentar asignar 3 en (1, 6) con costo 9
# Intentar asignar 3 en (1, 6) con costo 9
# Intentar asignar 3 en (1, 6) con costo 9
# Intentar asignar 7 en (1, 6) con costo 9
# Intentar asignar 3 en (1, 6) con costo 9
# Intentar asignar 3 en (1, 6) con costo 9
# Intentar asignar 7 en (1, 6) con costo 9
# Intentar asignar 3 en (1, 6) con costo 9
# Intentar asignar 3 en (1, 6) con costo 9
# Intentar asignar 3 en (1, 6) con costo 9
# Intentar asignar 3 en (1, 6) con costo 9
# Intentar asignar 7 en (1, 6) con costo 9
# Intentar asignar 3 en (1, 6) con costo 9
# Intentar asignar 3 en (1, 6) con costo 9
# Intentar asignar 7 en (1, 6) con costo 9
# Intentar asignar 3 en (1, 6) con costo 9
# Intentar asignar 3 en (1, 6) con costo 9
# Intentar asignar 3 en (1, 6) con costo 9
# Intentar asignar 3 en (1, 6) con costo 9
# Intentar asignar 7 en (1, 6) con costo 9
# Intentar asignar 3 en (1, 6) con costo 9
# Intentar asignar 3 en (1, 6) con costo 9
# Intentar asignar 7 en (1, 6) con costo 9
# Intentar asignar 3 en (1, 6) con costo 9
# Intentar asignar 3 en (1, 6) con costo 9
# Intentar asignar 3 en (1, 6) con costo 9
# Intentar asignar 3 en (1, 6) con costo 9
# Intentar asignar 7 en (1, 6) con costo 9
# Intentar asignar 3 en (1, 6) con costo 9
# Intentar asignar 3 en (1, 6) con costo 9
# Intentar asignar 7 en (1, 6) con costo 9
# Intentar asignar 3 en (1, 6) con costo 9
# Intentar asignar 3 en (1, 6) con costo 9
# Intentar asignar 3 en (1, 6) con costo 9
# Intentar asignar 3 en (1, 6) con costo 9
# Intentar asignar 7 en (1, 6) con costo 9
# Intentar asignar 3 en (1, 6) con costo 9
# Intentar asignar 3 en (1, 6) con costo 9
# Intentar asignar 7 en (1, 6) con costo 9
# Intentar asignar 3 en (1, 6) con costo 9
# Intentar asignar 3 en (1, 6) con costo 9
# Intentar asignar 3 en (1, 6) con costo 9
# Intentar asignar 3 en (1, 6) con costo 9
# Intentar asignar 7 en (1, 6) con costo 9
# Intentar asignar 3 en (1, 6) con costo 9
# Intentar asignar 4 en (1, 6) con costo 9
# Intentar asignar 3 en (1, 6) con costo 9
# Intentar asignar 7 en (1, 6) con costo 9
# Intentar asignar 3 en (1, 6) con costo 9
# Intentar asignar 3 en (1, 6) con costo 9
# Intentar asignar 4 en (1, 6) con costo 9
# Intentar asignar 3 en (1, 6) con costo 9
# Intentar asignar 3 en (1, 6) con costo 9
# Intentar asignar 7 en (1, 6) con costo 9
# Intentar asignar 3 en (1, 6) con costo 9
# Intentar asignar 4 en (1, 6) con costo 9
# Intentar asignar 3 en (1, 6) con costo 9
# Intentar asignar 7 en (1, 6) con costo 9
# Intentar asignar 3 en (1, 6) con costo 9
# Intentar asignar 3 en (1, 6) con costo 9
# Intentar asignar 4 en (1, 6) con costo 9
# Intentar asignar 3 en (1, 6) con costo 9
# Intentar asignar 3 en (1, 6) con costo 9
# Intentar asignar 7 en (1, 6) con costo 9
# Intentar asignar 8 en (1, 6) con costo 9
# Intentar asignar 3 en (1, 6) con costo 9
# Intentar asignar 8 en (1, 6) con costo 9
# Intentar asignar 3 en (1, 6) con costo 9
# Intentar asignar 7 en (1, 6) con costo 9
# Intentar asignar 8 en (1, 6) con costo 9
# Intentar asignar 3 en (1, 6) con costo 9
# Intentar asignar 8 en (1, 6) con costo 9
# Intentar asignar 3 en (1, 6) con costo 9
# Intentar asignar 8 en (1, 6) con costo 9
# Intentar asignar 3 en (1, 6) con costo 9
# Intentar asignar 8 en (1, 6) con costo 9
# Intentar asignar 3 en (1, 6) con costo 9
# Intentar asignar 7 en (1, 6) con costo 9
# Intentar asignar 8 en (1, 6) con costo 9
# Intentar asignar 3 en (1, 6) con costo 9
# Intentar asignar 8 en (1, 6) con costo 9
# Intentar asignar 3 en (1, 6) con costo 9
# Intentar asignar 7 en (1, 6) con costo 9
# Intentar asignar 8 en (1, 6) con costo 9
# Intentar asignar 3 en (1, 6) con costo 9
# Intentar asignar 8 en (1, 6) con costo 9
# Intentar asignar 3 en (1, 6) con costo 9
# Intentar asignar 8 en (1, 6) con costo 9
# Intentar asignar 3 en (1, 6) con costo 9
# Intentar asignar 8 en (1, 6) con costo 9
# Intentar asignar 3 en (1, 6) con costo 9
# Intentar asignar 7 en (1, 6) con costo 9
# Intentar asignar 8 en (1, 6) con costo 9
# Intentar asignar 3 en (1, 6) con costo 9
# Intentar asignar 8 en (1, 6) con costo 9
# Intentar asignar 3 en (1, 6) con costo 9
# Intentar asignar 7 en (1, 6) con costo 9
# Intentar asignar 8 en (1, 6) con costo 9
# Intentar asignar 3 en (1, 6) con costo 9
# Intentar asignar 8 en (1, 6) con costo 9
# Intentar asignar 3 en (1, 6) con costo 9
# Intentar asignar 8 en (1, 6) con costo 9
# Intentar asignar 3 en (1, 6) con costo 9
# Intentar asignar 8 en (1, 6) con costo 9
# Intentar asignar 3 en (1, 6) con costo 9
# Intentar asignar 3 en (1, 6) con costo 9
# Intentar asignar 3 en (1, 6) con costo 9
# Intentar asignar 3 en (1, 6) con costo 9
# Intentar asignar 3 en (1, 6) con costo 9
# Intentar asignar 8 en (1, 6) con costo 9
# Intentar asignar 3 en (1, 6) con costo 9
# Intentar asignar 8 en (1, 6) con costo 9
# Intentar asignar 3 en (1, 6) con costo 9
# Intentar asignar 8 en (1, 6) con costo 9
# Intentar asignar 3 en (1, 6) con costo 9
# Intentar asignar 8 en (1, 6) con costo 9
# Intentar asignar 3 en (1, 6) con costo 9
# Intentar asignar 4 en (1, 6) con costo 9
# Intentar asignar 3 en (1, 6) con costo 9
# Intentar asignar 4 en (1, 6) con costo 9
# Intentar asignar 3 en (1, 6) con costo 9
# Intentar asignar 4 en (1, 6) con costo 9
# Intentar asignar 3 en (1, 6) con costo 9
# Intentar asignar 4 en (1, 6) con costo 9
# Intentar asignar 3 en (1, 6) con costo 9
# Intentar asignar 4 en (1, 6) con costo 9
# Intentar asignar 3 en (1, 6) con costo 9
# Intentar asignar 4 en (1, 6) con costo 9
# Intentar asignar 3 en (1, 6) con costo 9
# Intentar asignar 4 en (1, 6) con costo 9
# Intentar asignar 3 en (1, 6) con costo 9
# Intentar asignar 4 en (1, 6) con costo 9
# Intentar asignar 3 en (1, 6) con costo 9
# Intentar asignar 4 en (1, 6) con costo 9
# Intentar asignar 8 en (1, 6) con costo 9
# Intentar asignar 3 en (1, 6) con costo 9
# Intentar asignar 4 en (1, 6) con costo 9
# Intentar asignar 8 en (1, 6) con costo 9
# Intentar asignar 3 en (1, 6) con costo 9
# Intentar asignar 4 en (1, 6) con costo 9
# Intentar asignar 8 en (1, 6) con costo 9
# Intentar asignar 3 en (1, 6) con costo 9
# Intentar asignar 4 en (1, 6) con costo 9
# Intentar asignar 8 en (1, 6) con costo 9
# Intentar asignar 3 en (1, 7) con costo 10
# Intentar asignar 3 en (1, 7) con costo 10
# Intentar asignar 2 en (1, 7) con costo 10
# Intentar asignar 2 en (1, 7) con costo 10
# Intentar asignar 3 en (1, 7) con costo 10
# Intentar asignar 3 en (1, 7) con costo 10
# Intentar asignar 2 en (1, 7) con costo 10
# Intentar asignar 2 en (1, 7) con costo 10
# Intentar asignar 3 en (1, 7) con costo 10
# Intentar asignar 3 en (1, 7) con costo 10
# Intentar asignar 2 en (1, 7) con costo 10
# Intentar asignar 2 en (1, 7) con costo 10
# Intentar asignar 3 en (1, 7) con costo 10
# Intentar asignar 3 en (1, 7) con costo 10
# Intentar asignar 2 en (1, 7) con costo 10
# Intentar asignar 2 en (1, 7) con costo 10
# Intentar asignar 3 en (1, 7) con costo 10
# Intentar asignar 3 en (1, 7) con costo 10
# Intentar asignar 2 en (1, 7) con costo 10
# Intentar asignar 2 en (1, 7) con costo 10
# Intentar asignar 3 en (1, 7) con costo 10
# Intentar asignar 3 en (1, 7) con costo 10
# Intentar asignar 2 en (1, 7) con costo 10
# Intentar asignar 2 en (1, 7) con costo 10
# Intentar asignar 3 en (1, 7) con costo 10
# Intentar asignar 4 en (1, 7) con costo 10
# Intentar asignar 3 en (1, 7) con costo 10
# Intentar asignar 3 en (1, 7) con costo 10
# Intentar asignar 4 en (1, 7) con costo 10
# Intentar asignar 3 en (1, 7) con costo 10
# Intentar asignar 3 en (1, 7) con costo 10
# Intentar asignar 4 en (1, 7) con costo 10
# Intentar asignar 3 en (1, 7) con costo 10
# Intentar asignar 3 en (1, 7) con costo 10
# Intentar asignar 4 en (1, 7) con costo 10
# Intentar asignar 3 en (1, 7) con costo 10
# Intentar asignar 3 en (1, 7) con costo 10
# Intentar asignar 3 en (1, 7) con costo 10
# Intentar asignar 3 en (1, 7) con costo 10
# Intentar asignar 3 en (1, 7) con costo 10
# Intentar asignar 3 en (1, 7) con costo 10
# Intentar asignar 3 en (1, 7) con costo 10
# Intentar asignar 3 en (1, 7) con costo 10
# Intentar asignar 3 en (1, 7) con costo 10
# Intentar asignar 3 en (1, 7) con costo 10
# Intentar asignar 3 en (1, 7) con costo 10
# Intentar asignar 3 en (1, 7) con costo 10
# Intentar asignar 3 en (1, 7) con costo 10
# Intentar asignar 3 en (1, 7) con costo 10
# Intentar asignar 3 en (1, 7) con costo 10
# Intentar asignar 3 en (1, 7) con costo 10
# Intentar asignar 3 en (1, 7) con costo 10
# Intentar asignar 3 en (1, 7) con costo 10
# Intentar asignar 3 en (1, 7) con costo 10
# Intentar asignar 3 en (1, 7) con costo 10
# Intentar asignar 3 en (1, 7) con costo 10
# Intentar asignar 3 en (1, 7) con costo 10
# Intentar asignar 3 en (1, 7) con costo 10
# Intentar asignar 3 en (1, 7) con costo 10
# Intentar asignar 3 en (1, 7) con costo 10
# Intentar asignar 2 en (1, 7) con costo 10
# Intentar asignar 2 en (1, 7) con costo 10
# Intentar asignar 2 en (1, 7) con costo 10
# Intentar asignar 2 en (1, 7) con costo 10
# Intentar asignar 2 en (1, 7) con costo 10
# Intentar asignar 2 en (1, 7) con costo 10
# Intentar asignar 3 en (1, 7) con costo 10
# Intentar asignar 2 en (1, 7) con costo 10
# Intentar asignar 2 en (1, 7) con costo 10
# Intentar asignar 3 en (1, 7) con costo 10
# Intentar asignar 2 en (1, 7) con costo 10
# Intentar asignar 2 en (1, 7) con costo 10
# Intentar asignar 3 en (1, 7) con costo 10
# Intentar asignar 2 en (1, 7) con costo 10
# Intentar asignar 2 en (1, 7) con costo 10
# Intentar asignar 3 en (1, 7) con costo 10
# Intentar asignar 4 en (1, 7) con costo 10
# Intentar asignar 3 en (1, 7) con costo 10
# Intentar asignar 4 en (1, 7) con costo 10
# Intentar asignar 3 en (1, 7) con costo 10
# Intentar asignar 4 en (1, 7) con costo 10
# Intentar asignar 3 en (1, 7) con costo 10
# Intentar asignar 4 en (1, 7) con costo 10
# Intentar asignar 3 en (1, 7) con costo 10
# Intentar asignar 4 en (1, 7) con costo 10
# Intentar asignar 3 en (1, 7) con costo 10
# Intentar asignar 4 en (1, 7) con costo 10
# Intentar asignar 3 en (1, 7) con costo 10
# Intentar asignar 4 en (1, 7) con costo 10
# Intentar asignar 3 en (1, 7) con costo 10
# Intentar asignar 4 en (1, 7) con costo 10
# Intentar asignar 3 en (1, 7) con costo 10
# Intentar asignar 4 en (1, 7) con costo 10
# Intentar asignar 3 en (1, 7) con costo 10
# Intentar asignar 3 en (1, 7) con costo 10
# Intentar asignar 4 en (1, 7) con costo 10
# Intentar asignar 4 en (1, 7) con costo 10
# Intentar asignar 3 en (1, 7) con costo 10
# Intentar asignar 3 en (1, 7) con costo 10
# Intentar asignar 4 en (1, 7) con costo 10
# Intentar asignar 4 en (1, 7) con costo 10
# Intentar asignar 3 en (1, 7) con costo 10
# Intentar asignar 3 en (1, 7) con costo 10
# Intentar asignar 4 en (1, 7) con costo 10
# Intentar asignar 4 en (1, 7) con costo 10
# Intentar asignar 3 en (1, 7) con costo 10
# Intentar asignar 3 en (1, 7) con costo 10
# Intentar asignar 4 en (1, 7) con costo 10
# Intentar asignar 8 en (1, 8) con costo 11
# Intentar asignar 7 en (1, 8) con costo 11
# Intentar asignar 8 en (1, 8) con costo 11
# Intentar asignar 7 en (1, 8) con costo 11
# Intentar asignar 8 en (1, 8) con costo 11
# Intentar asignar 7 en (1, 8) con costo 11
# Intentar asignar 8 en (1, 8) con costo 11
# Intentar asignar 7 en (1, 8) con costo 11
# Intentar asignar 8 en (1, 8) con costo 11
# Intentar asignar 7 en (1, 8) con costo 11
# Intentar asignar 8 en (1, 8) con costo 11
# Intentar asignar 7 en (1, 8) con costo 11
# Intentar asignar 8 en (1, 8) con costo 11
# Intentar asignar 2 en (1, 8) con costo 11
# Intentar asignar 8 en (1, 8) con costo 11
# Intentar asignar 2 en (1, 8) con costo 11
# Intentar asignar 8 en (1, 8) con costo 11
# Intentar asignar 2 en (1, 8) con costo 11
# Intentar asignar 8 en (1, 8) con costo 11
# Intentar asignar 2 en (1, 8) con costo 11
# Intentar asignar 8 en (1, 8) con costo 11
# Intentar asignar 8 en (1, 8) con costo 11
# Intentar asignar 4 en (1, 8) con costo 11
# Intentar asignar 8 en (1, 8) con costo 11
# Intentar asignar 8 en (1, 8) con costo 11
# Intentar asignar 4 en (1, 8) con costo 11
# Intentar asignar 8 en (1, 8) con costo 11
# Intentar asignar 8 en (1, 8) con costo 11
# Intentar asignar 4 en (1, 8) con costo 11
# Intentar asignar 8 en (1, 8) con costo 11
# Intentar asignar 8 en (1, 8) con costo 11
# Intentar asignar 4 en (1, 8) con costo 11
# Intentar asignar 1 en (2, 0) con costo 12
# Intentar asignar 1 en (2, 0) con costo 12
# Intentar asignar 1 en (2, 0) con costo 12
# Intentar asignar 1 en (2, 0) con costo 12
# Intentar asignar 1 en (2, 0) con costo 12
# Intentar asignar 1 en (2, 0) con costo 12
# Intentar asignar 1 en (2, 0) con costo 12
# Intentar asignar 1 en (2, 0) con costo 12
# Intentar asignar 1 en (2, 0) con costo 12
# Intentar asignar 1 en (2, 0) con costo 12
# Intentar asignar 1 en (2, 0) con costo 12
# Intentar asignar 1 en (2, 0) con costo 12
# Intentar asignar 1 en (2, 0) con costo 12
# Intentar asignar 1 en (2, 0) con costo 12
# Intentar asignar 1 en (2, 0) con costo 12
# Intentar asignar 1 en (2, 0) con costo 12
# Intentar asignar 1 en (2, 0) con costo 12
# Intentar asignar 1 en (2, 0) con costo 12
# Intentar asignar 1 en (2, 0) con costo 12
# Intentar asignar 1 en (2, 0) con costo 12
# Intentar asignar 2 en (2, 3) con costo 13
# Intentar asignar 3 en (2, 3) con costo 13
# Intentar asignar 2 en (2, 3) con costo 13
# Intentar asignar 3 en (2, 3) con costo 13
# Intentar asignar 2 en (2, 3) con costo 13
# Intentar asignar 3 en (2, 3) con costo 13
# Intentar asignar 2 en (2, 3) con costo 13
# Intentar asignar 3 en (2, 3) con costo 13
# Intentar asignar 2 en (2, 3) con costo 13
# Intentar asignar 3 en (2, 3) con costo 13
# Intentar asignar 2 en (2, 3) con costo 13
# Intentar asignar 3 en (2, 3) con costo 13
# Intentar asignar 2 en (2, 3) con costo 13
# Intentar asignar 3 en (2, 3) con costo 13
# Intentar asignar 2 en (2, 3) con costo 13
# Intentar asignar 3 en (2, 3) con costo 13
# Intentar asignar 2 en (2, 3) con costo 13
# Intentar asignar 3 en (2, 3) con costo 13
# Intentar asignar 2 en (2, 3) con costo 13
# Intentar asignar 3 en (2, 3) con costo 13
# Intentar asignar 2 en (2, 3) con costo 13
# Intentar asignar 3 en (2, 3) con costo 13
# Intentar asignar 2 en (2, 3) con costo 13
# Intentar asignar 3 en (2, 3) con costo 13
# Intentar asignar 2 en (2, 3) con costo 13
# Intentar asignar 3 en (2, 3) con costo 13
# Intentar asignar 2 en (2, 3) con costo 13
# Intentar asignar 3 en (2, 3) con costo 13
# Intentar asignar 2 en (2, 3) con costo 13
# Intentar asignar 3 en (2, 3) con costo 13
# Intentar asignar 2 en (2, 3) con costo 13
# Intentar asignar 3 en (2, 3) con costo 13
# Intentar asignar 2 en (2, 3) con costo 13
# Intentar asignar 3 en (2, 3) con costo 13
# Intentar asignar 2 en (2, 3) con costo 13
# Intentar asignar 3 en (2, 3) con costo 13
# Intentar asignar 2 en (2, 3) con costo 13
# Intentar asignar 3 en (2, 3) con costo 13
# Intentar asignar 2 en (2, 3) con costo 13
# Intentar asignar 3 en (2, 3) con costo 13
# Intentar asignar 3 en (2, 4) con costo 14
# Intentar asignar 4 en (2, 4) con costo 14
# Intentar asignar 4 en (2, 4) con costo 14
# Intentar asignar 3 en (2, 4) con costo 14
# Intentar asignar 4 en (2, 4) con costo 14
# Intentar asignar 4 en (2, 4) con costo 14
# Intentar asignar 3 en (2, 4) con costo 14
# Intentar asignar 4 en (2, 4) con costo 14
# Intentar asignar 4 en (2, 4) con costo 14
# Intentar asignar 3 en (2, 4) con costo 14
# Intentar asignar 4 en (2, 4) con costo 14
# Intentar asignar 4 en (2, 4) con costo 14
# Intentar asignar 3 en (2, 4) con costo 14
# Intentar asignar 4 en (2, 4) con costo 14
# Intentar asignar 4 en (2, 4) con costo 14
# Intentar asignar 3 en (2, 4) con costo 14
# Intentar asignar 4 en (2, 4) con costo 14
# Intentar asignar 4 en (2, 4) con costo 14
# Intentar asignar 3 en (2, 4) con costo 14
# Intentar asignar 4 en (2, 4) con costo 14
# Intentar asignar 4 en (2, 4) con costo 14
# Intentar asignar 3 en (2, 4) con costo 14
# Intentar asignar 4 en (2, 4) con costo 14
# Intentar asignar 4 en (2, 4) con costo 14
# Intentar asignar 3 en (2, 4) con costo 14
# Intentar asignar 4 en (2, 4) con costo 14
# Intentar asignar 4 en (2, 4) con costo 14
# Intentar asignar 3 en (2, 4) con costo 14
# Intentar asignar 4 en (2, 4) con costo 14
# Intentar asignar 4 en (2, 4) con costo 14
# Intentar asignar 3 en (2, 4) con costo 14
# Intentar asignar 4 en (2, 4) con costo 14
# Intentar asignar 4 en (2, 4) con costo 14
# Intentar asignar 3 en (2, 4) con costo 14
# Intentar asignar 4 en (2, 4) con costo 14
# Intentar asignar 4 en (2, 4) con costo 14
# Intentar asignar 3 en (2, 4) con costo 14
# Intentar asignar 4 en (2, 4) con costo 14
# Intentar asignar 4 en (2, 4) con costo 14
# Intentar asignar 3 en (2, 4) con costo 14
# Intentar asignar 4 en (2, 4) con costo 14
# Intentar asignar 4 en (2, 4) con costo 14
# Intentar asignar 3 en (2, 4) con costo 14
# Intentar asignar 4 en (2, 4) con costo 14
# Intentar asignar 4 en (2, 4) con costo 14
# Intentar asignar 3 en (2, 4) con costo 14
# Intentar asignar 4 en (2, 4) con costo 14
# Intentar asignar 4 en (2, 4) con costo 14
# Intentar asignar 3 en (2, 4) con costo 14
# Intentar asignar 4 en (2, 4) con costo 14
# Intentar asignar 4 en (2, 4) con costo 14
# Intentar asignar 3 en (2, 4) con costo 14
# Intentar asignar 4 en (2, 4) con costo 14
# Intentar asignar 4 en (2, 4) con costo 14
# Intentar asignar 3 en (2, 4) con costo 14
# Intentar asignar 4 en (2, 4) con costo 14
# Intentar asignar 4 en (2, 4) con costo 14
# Intentar asignar 3 en (2, 4) con costo 14
# Intentar asignar 4 en (2, 4) con costo 14
# Intentar asignar 4 en (2, 4) con costo 14
# Intentar asignar 4 en (2, 5) con costo 15
# Intentar asignar 2 en (2, 5) con costo 15
# Intentar asignar 4 en (2, 5) con costo 15
# Intentar asignar 2 en (2, 5) con costo 15
# Intentar asignar 4 en (2, 5) con costo 15
# Intentar asignar 2 en (2, 5) con costo 15
# Intentar asignar 4 en (2, 5) con costo 15
# Intentar asignar 2 en (2, 5) con costo 15
# Intentar asignar 4 en (2, 5) con costo 15
# Intentar asignar 2 en (2, 5) con costo 15
# Intentar asignar 4 en (2, 5) con costo 15
# Intentar asignar 2 en (2, 5) con costo 15
# Intentar asignar 4 en (2, 5) con costo 15
# Intentar asignar 2 en (2, 5) con costo 15
# Intentar asignar 4 en (2, 5) con costo 15
# Intentar asignar 2 en (2, 5) con costo 15
# Intentar asignar 4 en (2, 5) con costo 15
# Intentar asignar 2 en (2, 5) con costo 15
# Intentar asignar 4 en (2, 5) con costo 15
# Intentar asignar 2 en (2, 5) con costo 15
# Intentar asignar 4 en (2, 5) con costo 15
# Intentar asignar 2 en (2, 5) con costo 15
# Intentar asignar 4 en (2, 5) con costo 15
# Intentar asignar 2 en (2, 5) con costo 15
# Intentar asignar 4 en (2, 5) con costo 15
# Intentar asignar 2 en (2, 5) con costo 15
# Intentar asignar 4 en (2, 5) con costo 15
# Intentar asignar 2 en (2, 5) con costo 15
# Intentar asignar 4 en (2, 5) con costo 15
# Intentar asignar 2 en (2, 5) con costo 15
# Intentar asignar 4 en (2, 5) con costo 15
# Intentar asignar 2 en (2, 5) con costo 15
# Intentar asignar 4 en (2, 5) con costo 15
# Intentar asignar 2 en (2, 5) con costo 15
# Intentar asignar 4 en (2, 5) con costo 15
# Intentar asignar 2 en (2, 5) con costo 15
# Intentar asignar 4 en (2, 5) con costo 15
# Intentar asignar 2 en (2, 5) con costo 15
# Intentar asignar 4 en (2, 5) con costo 15
# Intentar asignar 2 en (2, 5) con costo 15
# Intentar asignar 5 en (2, 6) con costo 16
# Intentar asignar 7 en (2, 6) con costo 16
# Intentar asignar 5 en (2, 6) con costo 16
# Intentar asignar 7 en (2, 6) con costo 16
# Intentar asignar 5 en (2, 6) con costo 16
# Intentar asignar 7 en (2, 6) con costo 16
# Intentar asignar 5 en (2, 6) con costo 16
# Intentar asignar 7 en (2, 6) con costo 16
# Intentar asignar 5 en (2, 6) con costo 16
# Intentar asignar 7 en (2, 6) con costo 16
# Intentar asignar 5 en (2, 6) con costo 16
# Intentar asignar 7 en (2, 6) con costo 16
# Intentar asignar 5 en (2, 6) con costo 16
# Intentar asignar 7 en (2, 6) con costo 16
# Intentar asignar 5 en (2, 6) con costo 16
# Intentar asignar 7 en (2, 6) con costo 16
# Intentar asignar 5 en (2, 6) con costo 16
# Intentar asignar 7 en (2, 6) con costo 16
# Intentar asignar 5 en (2, 6) con costo 16
# Intentar asignar 7 en (2, 6) con costo 16
# Intentar asignar 5 en (2, 6) con costo 16
# Intentar asignar 7 en (2, 6) con costo 16
# Intentar asignar 5 en (2, 6) con costo 16
# Intentar asignar 7 en (2, 6) con costo 16
# Intentar asignar 5 en (2, 6) con costo 16
# Intentar asignar 7 en (2, 6) con costo 16
# Intentar asignar 5 en (2, 6) con costo 16
# Intentar asignar 7 en (2, 6) con costo 16
# Intentar asignar 5 en (2, 6) con costo 16
# Intentar asignar 7 en (2, 6) con costo 16
# Intentar asignar 5 en (2, 6) con costo 16
# Intentar asignar 7 en (2, 6) con costo 16
# Intentar asignar 5 en (2, 6) con costo 16
# Intentar asignar 7 en (2, 6) con costo 16
# Intentar asignar 5 en (2, 6) con costo 16
# Intentar asignar 7 en (2, 6) con costo 16
# Intentar asignar 5 en (2, 6) con costo 16
# Intentar asignar 7 en (2, 6) con costo 16
# Intentar asignar 5 en (2, 6) con costo 16
# Intentar asignar 7 en (2, 6) con costo 16
# Intentar asignar 5 en (2, 6) con costo 16
# Intentar asignar 7 en (2, 6) con costo 16
# Intentar asignar 5 en (2, 6) con costo 16
# Intentar asignar 7 en (2, 6) con costo 16
# Intentar asignar 5 en (2, 6) con costo 16
# Intentar asignar 7 en (2, 6) con costo 16
# Intentar asignar 5 en (2, 6) con costo 16
# Intentar asignar 7 en (2, 6) con costo 16
# Intentar asignar 5 en (2, 6) con costo 16
# Intentar asignar 7 en (2, 6) con costo 16
# Intentar asignar 5 en (2, 6) con costo 16
# Intentar asignar 7 en (2, 6) con costo 16
# Intentar asignar 5 en (2, 6) con costo 16
# Intentar asignar 7 en (2, 6) con costo 16
# Intentar asignar 5 en (2, 6) con costo 16
# Intentar asignar 7 en (2, 6) con costo 16
# Intentar asignar 5 en (2, 6) con costo 16
# Intentar asignar 7 en (2, 6) con costo 16
# Intentar asignar 5 en (2, 6) con costo 16
# Intentar asignar 7 en (2, 6) con costo 16
# Intentar asignar 5 en (2, 6) con costo 16
# Intentar asignar 7 en (2, 6) con costo 16
# Intentar asignar 5 en (2, 6) con costo 16
# Intentar asignar 7 en (2, 6) con costo 16
# Intentar asignar 5 en (2, 6) con costo 16
# Intentar asignar 7 en (2, 6) con costo 16
# Intentar asignar 5 en (2, 6) con costo 16
# Intentar asignar 7 en (2, 6) con costo 16
# Intentar asignar 5 en (2, 6) con costo 16
# Intentar asignar 7 en (2, 6) con costo 16
# Intentar asignar 5 en (2, 6) con costo 16
# Intentar asignar 7 en (2, 6) con costo 16
# Intentar asignar 5 en (2, 6) con costo 16
# Intentar asignar 7 en (2, 6) con costo 16
# Intentar asignar 5 en (2, 6) con costo 16
# Intentar asignar 7 en (2, 6) con costo 16
# Intentar asignar 5 en (2, 6) con costo 16
# Intentar asignar 7 en (2, 6) con costo 16
# Intentar asignar 5 en (2, 6) con costo 16
# Intentar asignar 7 en (2, 6) con costo 16
# Intentar asignar 7 en (2, 8) con costo 17
# Intentar asignar 7 en (2, 8) con costo 17
# Intentar asignar 7 en (2, 8) con costo 17
# Intentar asignar 7 en (2, 8) con costo 17
# Intentar asignar 7 en (2, 8) con costo 17
# Intentar asignar 7 en (2, 8) con costo 17
# Intentar asignar 7 en (2, 8) con costo 17
# Intentar asignar 7 en (2, 8) con costo 17
# Intentar asignar 7 en (2, 8) con costo 17
# Intentar asignar 7 en (2, 8) con costo 17
# Intentar asignar 7 en (2, 8) con costo 17
# Intentar asignar 7 en (2, 8) con costo 17
# Intentar asignar 7 en (2, 8) con costo 17
# Intentar asignar 7 en (2, 8) con costo 17
# Intentar asignar 7 en (2, 8) con costo 17
# Intentar asignar 7 en (2, 8) con costo 17
# Intentar asignar 7 en (2, 8) con costo 17
# Intentar asignar 7 en (2, 8) con costo 17
# Intentar asignar 7 en (2, 8) con costo 17
# Intentar asignar 7 en (2, 8) con costo 17
# Intentar asignar 7 en (2, 8) con costo 17
# Intentar asignar 7 en (2, 8) con costo 17
# Intentar asignar 7 en (2, 8) con costo 17
# Intentar asignar 7 en (2, 8) con costo 17
# Intentar asignar 7 en (2, 8) con costo 17
# Intentar asignar 7 en (2, 8) con costo 17
# Intentar asignar 7 en (2, 8) con costo 17
# Intentar asignar 7 en (2, 8) con costo 17
# Intentar asignar 7 en (2, 8) con costo 17
# Intentar asignar 7 en (2, 8) con costo 17
# Intentar asignar 7 en (2, 8) con costo 17
# Intentar asignar 7 en (2, 8) con costo 17
# Intentar asignar 7 en (2, 8) con costo 17
# Intentar asignar 7 en (2, 8) con costo 17
# Intentar asignar 7 en (2, 8) con costo 17
# Intentar asignar 7 en (2, 8) con costo 17
# Intentar asignar 7 en (2, 8) con costo 17
# Intentar asignar 7 en (2, 8) con costo 17
# Intentar asignar 7 en (2, 8) con costo 17
# Intentar asignar 7 en (2, 8) con costo 17
# Intentar asignar 1 en (3, 1) con costo 18
# Intentar asignar 2 en (3, 1) con costo 18
# Intentar asignar 5 en (3, 1) con costo 18
# Intentar asignar 1 en (3, 1) con costo 18
# Intentar asignar 2 en (3, 1) con costo 18
# Intentar asignar 5 en (3, 1) con costo 18
# Intentar asignar 1 en (3, 1) con costo 18
# Intentar asignar 2 en (3, 1) con costo 18
# Intentar asignar 5 en (3, 1) con costo 18
# Intentar asignar 1 en (3, 1) con costo 18
# Intentar asignar 2 en (3, 1) con costo 18
# Intentar asignar 5 en (3, 1) con costo 18
# Intentar asignar 1 en (3, 1) con costo 18
# Intentar asignar 2 en (3, 1) con costo 18
# Intentar asignar 5 en (3, 1) con costo 18
# Intentar asignar 1 en (3, 1) con costo 18
# Intentar asignar 2 en (3, 1) con costo 18
# Intentar asignar 5 en (3, 1) con costo 18
# Intentar asignar 1 en (3, 1) con costo 18
# Intentar asignar 2 en (3, 1) con costo 18
# Intentar asignar 5 en (3, 1) con costo 18
# Intentar asignar 1 en (3, 1) con costo 18
# Intentar asignar 2 en (3, 1) con costo 18
# Intentar asignar 5 en (3, 1) con costo 18
# Intentar asignar 1 en (3, 1) con costo 18
# Intentar asignar 2 en (3, 1) con costo 18
# Intentar asignar 5 en (3, 1) con costo 18
# Intentar asignar 1 en (3, 1) con costo 18
# Intentar asignar 2 en (3, 1) con costo 18
# Intentar asignar 5 en (3, 1) con costo 18
# Intentar asignar 1 en (3, 1) con costo 18
# Intentar asignar 2 en (3, 1) con costo 18
# Intentar asignar 5 en (3, 1) con costo 18
# Intentar asignar 1 en (3, 1) con costo 18
# Intentar asignar 2 en (3, 1) con costo 18
# Intentar asignar 5 en (3, 1) con costo 18
# Intentar asignar 1 en (3, 1) con costo 18
# Intentar asignar 2 en (3, 1) con costo 18
# Intentar asignar 5 en (3, 1) con costo 18
# Intentar asignar 1 en (3, 1) con costo 18
# Intentar asignar 2 en (3, 1) con costo 18
# Intentar asignar 5 en (3, 1) con costo 18
# Intentar asignar 1 en (3, 1) con costo 18
# Intentar asignar 2 en (3, 1) con costo 18
# Intentar asignar 5 en (3, 1) con costo 18
# Intentar asignar 1 en (3, 1) con costo 18
# Intentar asignar 2 en (3, 1) con costo 18
# Intentar asignar 5 en (3, 1) con costo 18
# Intentar asignar 1 en (3, 1) con costo 18
# Intentar asignar 5 en (3, 1) con costo 18
# Intentar asignar 1 en (3, 1) con costo 18
# Intentar asignar 5 en (3, 1) con costo 18
# Intentar asignar 1 en (3, 1) con costo 18
# Intentar asignar 5 en (3, 1) con costo 18
# Intentar asignar 1 en (3, 1) con costo 18
# Intentar asignar 5 en (3, 1) con costo 18
# Intentar asignar 1 en (3, 1) con costo 18
# Intentar asignar 5 en (3, 1) con costo 18
# Intentar asignar 1 en (3, 1) con costo 18
# Intentar asignar 5 en (3, 1) con costo 18
# Intentar asignar 1 en (3, 1) con costo 18
# Intentar asignar 2 en (3, 1) con costo 18
# Intentar asignar 5 en (3, 1) con costo 18
# Intentar asignar 1 en (3, 1) con costo 18
# Intentar asignar 2 en (3, 1) con costo 18
# Intentar asignar 5 en (3, 1) con costo 18
# Intentar asignar 1 en (3, 1) con costo 18
# Intentar asignar 2 en (3, 1) con costo 18
# Intentar asignar 5 en (3, 1) con costo 18
# Intentar asignar 1 en (3, 1) con costo 18
# Intentar asignar 2 en (3, 1) con costo 18
# Intentar asignar 5 en (3, 1) con costo 18
# Intentar asignar 1 en (3, 1) con costo 18
# Intentar asignar 2 en (3, 1) con costo 18
# Intentar asignar 5 en (3, 1) con costo 18
# Intentar asignar 1 en (3, 1) con costo 18
# Intentar asignar 2 en (3, 1) con costo 18
# Intentar asignar 5 en (3, 1) con costo 18
# Intentar asignar 1 en (3, 1) con costo 18
# Intentar asignar 5 en (3, 1) con costo 18
# Intentar asignar 1 en (3, 1) con costo 18
# Intentar asignar 5 en (3, 1) con costo 18
# Intentar asignar 1 en (3, 1) con costo 18
# Intentar asignar 5 en (3, 1) con costo 18
# Intentar asignar 1 en (3, 1) con costo 18
# Intentar asignar 5 en (3, 1) con costo 18
# Intentar asignar 1 en (3, 1) con costo 18
# Intentar asignar 5 en (3, 1) con costo 18
# Intentar asignar 1 en (3, 1) con costo 18
# Intentar asignar 5 en (3, 1) con costo 18
# Intentar asignar 1 en (3, 1) con costo 18
# Intentar asignar 2 en (3, 1) con costo 18
# Intentar asignar 5 en (3, 1) con costo 18
# Intentar asignar 1 en (3, 1) con costo 18
# Intentar asignar 2 en (3, 1) con costo 18
# Intentar asignar 5 en (3, 1) con costo 18
# Intentar asignar 1 en (3, 1) con costo 18
# Intentar asignar 2 en (3, 1) con costo 18
# Intentar asignar 5 en (3, 1) con costo 18
# Intentar asignar 1 en (3, 1) con costo 18
# Intentar asignar 2 en (3, 1) con costo 18
# Intentar asignar 5 en (3, 1) con costo 18
# Intentar asignar 1 en (3, 1) con costo 18
# Intentar asignar 2 en (3, 1) con costo 18
# Intentar asignar 5 en (3, 1) con costo 18
# Intentar asignar 1 en (3, 1) con costo 18
# Intentar asignar 2 en (3, 1) con costo 18
# Intentar asignar 5 en (3, 1) con costo 18
# Intentar asignar 5 en (3, 2) con costo 19
# Intentar asignar 9 en (3, 2) con costo 19
# Intentar asignar 1 en (3, 2) con costo 19
# Intentar asignar 5 en (3, 2) con costo 19
# Intentar asignar 9 en (3, 2) con costo 19
# Intentar asignar 1 en (3, 2) con costo 19
# Intentar asignar 9 en (3, 2) con costo 19
# Intentar asignar 5 en (3, 2) con costo 19
# Intentar asignar 9 en (3, 2) con costo 19
# Intentar asignar 1 en (3, 2) con costo 19
# Intentar asignar 5 en (3, 2) con costo 19
# Intentar asignar 9 en (3, 2) con costo 19
# Intentar asignar 1 en (3, 2) con costo 19
# Intentar asignar 9 en (3, 2) con costo 19
# Intentar asignar 5 en (3, 2) con costo 19
# Intentar asignar 9 en (3, 2) con costo 19
# Intentar asignar 1 en (3, 2) con costo 19
# Intentar asignar 5 en (3, 2) con costo 19
# Intentar asignar 9 en (3, 2) con costo 19
# Intentar asignar 1 en (3, 2) con costo 19
# Intentar asignar 9 en (3, 2) con costo 19
# Intentar asignar 5 en (3, 2) con costo 19
# Intentar asignar 9 en (3, 2) con costo 19
# Intentar asignar 1 en (3, 2) con costo 19
# Intentar asignar 5 en (3, 2) con costo 19
# Intentar asignar 9 en (3, 2) con costo 19
# Intentar asignar 1 en (3, 2) con costo 19
# Intentar asignar 9 en (3, 2) con costo 19
# Intentar asignar 5 en (3, 2) con costo 19
# Intentar asignar 9 en (3, 2) con costo 19
# Intentar asignar 1 en (3, 2) con costo 19
# Intentar asignar 5 en (3, 2) con costo 19
# Intentar asignar 9 en (3, 2) con costo 19
# Intentar asignar 1 en (3, 2) con costo 19
# Intentar asignar 9 en (3, 2) con costo 19
# Intentar asignar 5 en (3, 2) con costo 19
# Intentar asignar 9 en (3, 2) con costo 19
# Intentar asignar 1 en (3, 2) con costo 19
# Intentar asignar 5 en (3, 2) con costo 19
# Intentar asignar 9 en (3, 2) con costo 19
# Intentar asignar 1 en (3, 2) con costo 19
# Intentar asignar 9 en (3, 2) con costo 19
# Intentar asignar 5 en (3, 2) con costo 19
# Intentar asignar 9 en (3, 2) con costo 19
# Intentar asignar 1 en (3, 2) con costo 19
# Intentar asignar 5 en (3, 2) con costo 19
# Intentar asignar 9 en (3, 2) con costo 19
# Intentar asignar 1 en (3, 2) con costo 19
# Intentar asignar 9 en (3, 2) con costo 19
# Intentar asignar 5 en (3, 2) con costo 19
# Intentar asignar 9 en (3, 2) con costo 19
# Intentar asignar 1 en (3, 2) con costo 19
# Intentar asignar 5 en (3, 2) con costo 19
# Intentar asignar 9 en (3, 2) con costo 19
# Intentar asignar 1 en (3, 2) con costo 19
# Intentar asignar 9 en (3, 2) con costo 19
# Intentar asignar 5 en (3, 2) con costo 19
# Intentar asignar 9 en (3, 2) con costo 19
# Intentar asignar 1 en (3, 2) con costo 19
# Intentar asignar 5 en (3, 2) con costo 19
# Intentar asignar 9 en (3, 2) con costo 19
# Intentar asignar 1 en (3, 2) con costo 19
# Intentar asignar 9 en (3, 2) con costo 19
# Intentar asignar 5 en (3, 2) con costo 19
# Intentar asignar 9 en (3, 2) con costo 19
# Intentar asignar 1 en (3, 2) con costo 19
# Intentar asignar 5 en (3, 2) con costo 19
# Intentar asignar 9 en (3, 2) con costo 19
# Intentar asignar 1 en (3, 2) con costo 19
# Intentar asignar 9 en (3, 2) con costo 19
# Intentar asignar 5 en (3, 2) con costo 19
# Intentar asignar 9 en (3, 2) con costo 19
# Intentar asignar 1 en (3, 2) con costo 19
# Intentar asignar 5 en (3, 2) con costo 19
# Intentar asignar 9 en (3, 2) con costo 19
# Intentar asignar 1 en (3, 2) con costo 19
# Intentar asignar 9 en (3, 2) con costo 19
# Intentar asignar 5 en (3, 2) con costo 19
# Intentar asignar 9 en (3, 2) con costo 19
# Intentar asignar 1 en (3, 2) con costo 19
# Intentar asignar 5 en (3, 2) con costo 19
# Intentar asignar 9 en (3, 2) con costo 19
# Intentar asignar 1 en (3, 2) con costo 19
# Intentar asignar 9 en (3, 2) con costo 19
# Intentar asignar 5 en (3, 2) con costo 19
# Intentar asignar 9 en (3, 2) con costo 19
# Intentar asignar 1 en (3, 2) con costo 19
# Intentar asignar 5 en (3, 2) con costo 19
# Intentar asignar 9 en (3, 2) con costo 19
# Intentar asignar 1 en (3, 2) con costo 19
# Intentar asignar 9 en (3, 2) con costo 19
# Intentar asignar 5 en (3, 2) con costo 19
# Intentar asignar 9 en (3, 2) con costo 19
# Intentar asignar 1 en (3, 2) con costo 19
# Intentar asignar 5 en (3, 2) con costo 19
# Intentar asignar 9 en (3, 2) con costo 19
# Intentar asignar 1 en (3, 2) con costo 19
# Intentar asignar 9 en (3, 2) con costo 19
# Intentar asignar 5 en (3, 2) con costo 19
# Intentar asignar 9 en (3, 2) con costo 19
# Intentar asignar 1 en (3, 2) con costo 19
# Intentar asignar 5 en (3, 2) con costo 19
# Intentar asignar 9 en (3, 2) con costo 19
# Intentar asignar 1 en (3, 2) con costo 19
# Intentar asignar 9 en (3, 2) con costo 19
# Intentar asignar 5 en (3, 2) con costo 19
# Intentar asignar 9 en (3, 2) con costo 19
# Intentar asignar 1 en (3, 2) con costo 19
# Intentar asignar 5 en (3, 2) con costo 19
# Intentar asignar 9 en (3, 2) con costo 19
# Intentar asignar 1 en (3, 2) con costo 19
# Intentar asignar 9 en (3, 2) con costo 19
# Intentar asignar 2 en (3, 2) con costo 19
# Intentar asignar 5 en (3, 2) con costo 19
# Intentar asignar 9 en (3, 2) con costo 19
# Intentar asignar 1 en (3, 2) con costo 19
# Intentar asignar 2 en (3, 2) con costo 19
# Intentar asignar 9 en (3, 2) con costo 19
# Intentar asignar 2 en (3, 2) con costo 19
# Intentar asignar 5 en (3, 2) con costo 19
# Intentar asignar 9 en (3, 2) con costo 19
# Intentar asignar 1 en (3, 2) con costo 19
# Intentar asignar 2 en (3, 2) con costo 19
# Intentar asignar 9 en (3, 2) con costo 19
# Intentar asignar 2 en (3, 2) con costo 19
# Intentar asignar 5 en (3, 2) con costo 19
# Intentar asignar 9 en (3, 2) con costo 19
# Intentar asignar 1 en (3, 2) con costo 19
# Intentar asignar 2 en (3, 2) con costo 19
# Intentar asignar 9 en (3, 2) con costo 19
# Intentar asignar 2 en (3, 2) con costo 19
# Intentar asignar 5 en (3, 2) con costo 19
# Intentar asignar 9 en (3, 2) con costo 19
# Intentar asignar 1 en (3, 2) con costo 19
# Intentar asignar 2 en (3, 2) con costo 19
# Intentar asignar 9 en (3, 2) con costo 19
# Intentar asignar 2 en (3, 2) con costo 19
# Intentar asignar 5 en (3, 2) con costo 19
# Intentar asignar 9 en (3, 2) con costo 19
# Intentar asignar 1 en (3, 2) con costo 19
# Intentar asignar 2 en (3, 2) con costo 19
# Intentar asignar 9 en (3, 2) con costo 19
# Intentar asignar 2 en (3, 2) con costo 19
# Intentar asignar 5 en (3, 2) con costo 19
# Intentar asignar 9 en (3, 2) con costo 19
# Intentar asignar 1 en (3, 2) con costo 19
# Intentar asignar 2 en (3, 2) con costo 19
# Intentar asignar 9 en (3, 2) con costo 19
# Intentar asignar 5 en (3, 2) con costo 19
# Intentar asignar 9 en (3, 2) con costo 19
# Intentar asignar 1 en (3, 2) con costo 19
# Intentar asignar 5 en (3, 2) con costo 19
# Intentar asignar 9 en (3, 2) con costo 19
# Intentar asignar 1 en (3, 2) con costo 19
# Intentar asignar 9 en (3, 2) con costo 19
# Intentar asignar 5 en (3, 2) con costo 19
# Intentar asignar 9 en (3, 2) con costo 19
# Intentar asignar 1 en (3, 2) con costo 19
# Intentar asignar 5 en (3, 2) con costo 19
# Intentar asignar 9 en (3, 2) con costo 19
# Intentar asignar 1 en (3, 2) con costo 19
# Intentar asignar 9 en (3, 2) con costo 19
# Intentar asignar 5 en (3, 2) con costo 19
# Intentar asignar 9 en (3, 2) con costo 19
# Intentar asignar 1 en (3, 2) con costo 19
# Intentar asignar 5 en (3, 2) con costo 19
# Intentar asignar 9 en (3, 2) con costo 19
# Intentar asignar 1 en (3, 2) con costo 19
# Intentar asignar 9 en (3, 2) con costo 19
# Intentar asignar 5 en (3, 2) con costo 19
# Intentar asignar 9 en (3, 2) con costo 19
# Intentar asignar 1 en (3, 2) con costo 19
# Intentar asignar 5 en (3, 2) con costo 19
# Intentar asignar 9 en (3, 2) con costo 19
# Intentar asignar 1 en (3, 2) con costo 19
# Intentar asignar 9 en (3, 2) con costo 19
# Intentar asignar 5 en (3, 2) con costo 19
# Intentar asignar 9 en (3, 2) con costo 19
# Intentar asignar 1 en (3, 2) con costo 19
# Intentar asignar 5 en (3, 2) con costo 19
# Intentar asignar 9 en (3, 2) con costo 19
# Intentar asignar 1 en (3, 2) con costo 19
# Intentar asignar 9 en (3, 2) con costo 19
# Intentar asignar 5 en (3, 2) con costo 19
# Intentar asignar 9 en (3, 2) con costo 19
# Intentar asignar 1 en (3, 2) con costo 19
# Intentar asignar 5 en (3, 2) con costo 19
# Intentar asignar 9 en (3, 2) con costo 19
# Intentar asignar 1 en (3, 2) con costo 19
# Intentar asignar 9 en (3, 2) con costo 19
# Intentar asignar 2 en (3, 2) con costo 19
# Intentar asignar 5 en (3, 2) con costo 19
# Intentar asignar 9 en (3, 2) con costo 19
# Intentar asignar 1 en (3, 2) con costo 19
# Intentar asignar 2 en (3, 2) con costo 19
# Intentar asignar 9 en (3, 2) con costo 19
# Intentar asignar 2 en (3, 2) con costo 19
# Intentar asignar 5 en (3, 2) con costo 19
# Intentar asignar 9 en (3, 2) con costo 19
# Intentar asignar 1 en (3, 2) con costo 19
# Intentar asignar 2 en (3, 2) con costo 19
# Intentar asignar 9 en (3, 2) con costo 19
# Intentar asignar 2 en (3, 2) con costo 19
# Intentar asignar 5 en (3, 2) con costo 19
# Intentar asignar 9 en (3, 2) con costo 19
# Intentar asignar 1 en (3, 2) con costo 19
# Intentar asignar 2 en (3, 2) con costo 19
# Intentar asignar 9 en (3, 2) con costo 19
# Intentar asignar 2 en (3, 2) con costo 19
# Intentar asignar 5 en (3, 2) con costo 19
# Intentar asignar 9 en (3, 2) con costo 19
# Intentar asignar 1 en (3, 2) con costo 19
# Intentar asignar 2 en (3, 2) con costo 19
# Intentar asignar 9 en (3, 2) con costo 19
# Intentar asignar 2 en (3, 2) con costo 19
# Intentar asignar 5 en (3, 2) con costo 19
# Intentar asignar 9 en (3, 2) con costo 19
# Intentar asignar 1 en (3, 2) con costo 19
# Intentar asignar 2 en (3, 2) con costo 19
# Intentar asignar 9 en (3, 2) con costo 19
# Intentar asignar 2 en (3, 2) con costo 19
# Intentar asignar 5 en (3, 2) con costo 19
# ...
# Intentar asignar 6 en (4, 2) con costo 25
# Intentar asignar 6 en (4, 2) con costo 25
# Intentar asignar 9 en (4, 2) con costo 25
# Intentar asignar 6 en (4, 2) con costo 25
# Intentar asignar 9 en (4, 2) con costo 25
# Intentar asignar 6 en (4, 2) con costo 25
# Intentar asignar 9 en (4, 2) con costo 25
# Intentar asignar 6 en (4, 2) con costo 25
# Intentar asignar 9 en (4, 2) con costo 25
# Intentar asignar 6 en (4, 2) con costo 25
# Intentar asignar 6 en (4, 2) con costo 25
# Intentar asignar 6 en (4, 2) con costo 25
# Intentar asignar 9 en (4, 2) con costo 25
# Intentar asignar 6 en (4, 2) con costo 25
# Intentar asignar 9 en (4, 2) con costo 25
# Intentar asignar 6 en (4, 2) con costo 25
# Intentar asignar 5 en (4, 4) con costo 26
# Intentar asignar 5 en (4, 4) con costo 26
# Intentar asignar 5 en (4, 4) con costo 26
# Intentar asignar 5 en (4, 4) con costo 26
# Intentar asignar 5 en (4, 4) con costo 26
# Intentar asignar 5 en (4, 4) con costo 26
# Intentar asignar 5 en (4, 4) con costo 26
# Intentar asignar 5 en (4, 4) con costo 26
# Intentar asignar 5 en (4, 4) con costo 26
# Intentar asignar 5 en (4, 4) con costo 26
# Intentar asignar 5 en (4, 4) con costo 26
# Intentar asignar 5 en (4, 4) con costo 26
# Intentar asignar 5 en (4, 4) con costo 26
# Intentar asignar 5 en (4, 4) con costo 26
# Intentar asignar 5 en (4, 4) con costo 26
# Intentar asignar 5 en (4, 4) con costo 26
# Intentar asignar 5 en (4, 4) con costo 26
# Intentar asignar 5 en (4, 4) con costo 26
# Intentar asignar 5 en (4, 4) con costo 26
# Intentar asignar 5 en (4, 4) con costo 26
# Intentar asignar 5 en (4, 4) con costo 26
# Intentar asignar 5 en (4, 4) con costo 26
# Intentar asignar 5 en (4, 4) con costo 26
# Intentar asignar 5 en (4, 4) con costo 26
# Intentar asignar 5 en (4, 4) con costo 26
# Intentar asignar 5 en (4, 4) con costo 26
# Intentar asignar 5 en (4, 4) con costo 26
# Intentar asignar 5 en (4, 4) con costo 26
# Intentar asignar 5 en (4, 4) con costo 26
# Intentar asignar 5 en (4, 4) con costo 26
# Intentar asignar 5 en (4, 4) con costo 26
# Intentar asignar 5 en (4, 4) con costo 26
# Intentar asignar 5 en (4, 4) con costo 26
# Intentar asignar 5 en (4, 4) con costo 26
# Intentar asignar 5 en (4, 4) con costo 26
# Intentar asignar 5 en (4, 4) con costo 26
# Intentar asignar 5 en (4, 4) con costo 26
# Intentar asignar 5 en (4, 4) con costo 26
# Intentar asignar 5 en (4, 4) con costo 26
# Intentar asignar 5 en (4, 4) con costo 26
# Intentar asignar 5 en (4, 4) con costo 26
# Intentar asignar 5 en (4, 4) con costo 26
# Intentar asignar 5 en (4, 4) con costo 26
# Intentar asignar 5 en (4, 4) con costo 26
# Intentar asignar 5 en (4, 4) con costo 26
# Intentar asignar 5 en (4, 4) con costo 26
# Intentar asignar 5 en (4, 4) con costo 26
# Intentar asignar 5 en (4, 4) con costo 26
# Intentar asignar 5 en (4, 4) con costo 26
# Intentar asignar 5 en (4, 4) con costo 26
# Intentar asignar 5 en (4, 4) con costo 26
# Intentar asignar 5 en (4, 4) con costo 26
# Intentar asignar 5 en (4, 4) con costo 26
# Intentar asignar 5 en (4, 4) con costo 26
# Intentar asignar 5 en (4, 4) con costo 26
# Intentar asignar 5 en (4, 4) con costo 26
# Intentar asignar 5 en (4, 4) con costo 26
# Intentar asignar 5 en (4, 4) con costo 26
# Intentar asignar 5 en (4, 4) con costo 26
# Intentar asignar 5 en (4, 4) con costo 26
# Intentar asignar 5 en (4, 4) con costo 26
# Intentar asignar 5 en (4, 4) con costo 26
# Intentar asignar 5 en (4, 4) con costo 26
# Intentar asignar 5 en (4, 4) con costo 26
# Intentar asignar 5 en (4, 4) con costo 26
# Intentar asignar 5 en (4, 4) con costo 26
# Intentar asignar 5 en (4, 4) con costo 26
# Intentar asignar 5 en (4, 4) con costo 26
# Intentar asignar 5 en (4, 4) con costo 26
# Intentar asignar 5 en (4, 4) con costo 26
# Intentar asignar 5 en (4, 4) con costo 26
# Intentar asignar 5 en (4, 4) con costo 26
# Intentar asignar 5 en (4, 4) con costo 26
# Intentar asignar 5 en (4, 4) con costo 26
# Intentar asignar 5 en (4, 4) con costo 26
# Intentar asignar 5 en (4, 4) con costo 26
# Intentar asignar 5 en (4, 4) con costo 26
# Intentar asignar 5 en (4, 4) con costo 26
# Intentar asignar 5 en (4, 4) con costo 26
# Intentar asignar 5 en (4, 4) con costo 26
# Intentar asignar 5 en (4, 4) con costo 26
# Intentar asignar 5 en (4, 4) con costo 26
# Intentar asignar 5 en (4, 4) con costo 26
# Intentar asignar 5 en (4, 4) con costo 26
# Intentar asignar 5 en (4, 4) con costo 26
# Intentar asignar 5 en (4, 4) con costo 26
# Intentar asignar 5 en (4, 4) con costo 26
# Intentar asignar 5 en (4, 4) con costo 26
# Intentar asignar 5 en (4, 4) con costo 26
# Intentar asignar 5 en (4, 4) con costo 26
# Intentar asignar 5 en (4, 4) con costo 26
# Intentar asignar 5 en (4, 4) con costo 26
# Intentar asignar 5 en (4, 4) con costo 26
# Intentar asignar 5 en (4, 4) con costo 26
# Intentar asignar 5 en (4, 4) con costo 26
# Intentar asignar 5 en (4, 4) con costo 26
# Intentar asignar 5 en (4, 4) con costo 26
# Intentar asignar 5 en (4, 4) con costo 26
# Intentar asignar 5 en (4, 4) con costo 26
# Intentar asignar 5 en (4, 4) con costo 26
# Intentar asignar 5 en (4, 4) con costo 26
# Intentar asignar 5 en (4, 4) con costo 26
# Intentar asignar 5 en (4, 4) con costo 26
# Intentar asignar 5 en (4, 4) con costo 26
# Intentar asignar 5 en (4, 4) con costo 26
# Intentar asignar 5 en (4, 4) con costo 26
# Intentar asignar 5 en (4, 4) con costo 26
# Intentar asignar 5 en (4, 4) con costo 26
# Intentar asignar 5 en (4, 4) con costo 26
# Intentar asignar 5 en (4, 4) con costo 26
# Intentar asignar 5 en (4, 4) con costo 26
# Intentar asignar 5 en (4, 4) con costo 26
# Intentar asignar 5 en (4, 4) con costo 26
# Intentar asignar 5 en (4, 4) con costo 26
# Intentar asignar 5 en (4, 4) con costo 26
# Intentar asignar 5 en (4, 4) con costo 26
# Intentar asignar 5 en (4, 4) con costo 26
# Intentar asignar 5 en (4, 4) con costo 26
# Intentar asignar 5 en (4, 4) con costo 26
# Intentar asignar 5 en (4, 4) con costo 26
# Intentar asignar 5 en (4, 4) con costo 26
# Intentar asignar 5 en (4, 4) con costo 26
# Intentar asignar 5 en (4, 4) con costo 26
# Intentar asignar 5 en (4, 4) con costo 26
# Intentar asignar 5 en (4, 4) con costo 26
# Intentar asignar 5 en (4, 4) con costo 26
# Intentar asignar 5 en (4, 4) con costo 26
# Intentar asignar 5 en (4, 4) con costo 26
# Intentar asignar 5 en (4, 4) con costo 26
# Intentar asignar 5 en (4, 4) con costo 26
# Intentar asignar 5 en (4, 4) con costo 26
# Intentar asignar 5 en (4, 4) con costo 26
# Intentar asignar 5 en (4, 4) con costo 26
# Intentar asignar 5 en (4, 4) con costo 26
# Intentar asignar 5 en (4, 4) con costo 26
# Intentar asignar 5 en (4, 4) con costo 26
# Intentar asignar 5 en (4, 4) con costo 26
# Intentar asignar 5 en (4, 4) con costo 26
# Intentar asignar 5 en (4, 4) con costo 26
# Intentar asignar 5 en (4, 4) con costo 26
# Intentar asignar 7 en (4, 6) con costo 27
# Intentar asignar 9 en (4, 6) con costo 27
# Intentar asignar 7 en (4, 6) con costo 27
# Intentar asignar 7 en (4, 6) con costo 27
# Intentar asignar 9 en (4, 6) con costo 27
# Intentar asignar 7 en (4, 6) con costo 27
# Intentar asignar 7 en (4, 6) con costo 27
# Intentar asignar 9 en (4, 6) con costo 27
# Intentar asignar 7 en (4, 6) con costo 27
# Intentar asignar 7 en (4, 6) con costo 27
# Intentar asignar 9 en (4, 6) con costo 27
# Intentar asignar 7 en (4, 6) con costo 27
# Intentar asignar 9 en (4, 6) con costo 27
# Intentar asignar 7 en (4, 6) con costo 27
# Intentar asignar 7 en (4, 6) con costo 27
# Intentar asignar 7 en (4, 6) con costo 27
# Intentar asignar 9 en (4, 6) con costo 27
# Intentar asignar 7 en (4, 6) con costo 27
# Intentar asignar 9 en (4, 6) con costo 27
# Intentar asignar 7 en (4, 6) con costo 27
# Intentar asignar 7 en (4, 6) con costo 27
# Intentar asignar 9 en (4, 6) con costo 27
# Intentar asignar 7 en (4, 6) con costo 27
# Intentar asignar 9 en (4, 6) con costo 27
# Intentar asignar 7 en (4, 6) con costo 27
# Intentar asignar 7 en (4, 6) con costo 27
# Intentar asignar 9 en (4, 6) con costo 27
# Intentar asignar 7 en (4, 6) con costo 27
# Intentar asignar 7 en (4, 6) con costo 27
# Intentar asignar 9 en (4, 6) con costo 27
# Intentar asignar 7 en (4, 6) con costo 27
# Intentar asignar 7 en (4, 6) con costo 27
# Intentar asignar 9 en (4, 6) con costo 27
# Intentar asignar 7 en (4, 6) con costo 27
# Intentar asignar 9 en (4, 6) con costo 27
# Intentar asignar 7 en (4, 6) con costo 27
# Intentar asignar 7 en (4, 6) con costo 27
# Intentar asignar 7 en (4, 6) con costo 27
# Intentar asignar 9 en (4, 6) con costo 27
# Intentar asignar 7 en (4, 6) con costo 27
# Intentar asignar 9 en (4, 6) con costo 27
# Intentar asignar 7 en (4, 6) con costo 27
# Intentar asignar 7 en (4, 6) con costo 27
# Intentar asignar 9 en (4, 6) con costo 27
# Intentar asignar 7 en (4, 6) con costo 27
# Intentar asignar 7 en (4, 6) con costo 27
# Intentar asignar 7 en (4, 6) con costo 27
# Intentar asignar 7 en (4, 6) con costo 27
# Intentar asignar 7 en (4, 6) con costo 27
# Intentar asignar 7 en (4, 6) con costo 27
# Intentar asignar 7 en (4, 6) con costo 27
# Intentar asignar 7 en (4, 6) con costo 27
# Intentar asignar 7 en (4, 6) con costo 27
# Intentar asignar 7 en (4, 6) con costo 27
# Intentar asignar 7 en (4, 6) con costo 27
# Intentar asignar 7 en (4, 6) con costo 27
# Intentar asignar 7 en (4, 6) con costo 27
# Intentar asignar 7 en (4, 6) con costo 27
# Intentar asignar 7 en (4, 6) con costo 27
# Intentar asignar 7 en (4, 6) con costo 27
# Intentar asignar 7 en (4, 6) con costo 27
# Intentar asignar 7 en (4, 6) con costo 27
# Intentar asignar 7 en (4, 6) con costo 27
# Intentar asignar 7 en (4, 6) con costo 27
# Intentar asignar 7 en (4, 6) con costo 27
# Intentar asignar 9 en (4, 6) con costo 27
# Intentar asignar 7 en (4, 6) con costo 27
# Intentar asignar 7 en (4, 6) con costo 27
# Intentar asignar 9 en (4, 6) con costo 27
# Intentar asignar 7 en (4, 6) con costo 27
# Intentar asignar 7 en (4, 6) con costo 27
# Intentar asignar 9 en (4, 6) con costo 27
# Intentar asignar 7 en (4, 6) con costo 27
# Intentar asignar 7 en (4, 6) con costo 27
# Intentar asignar 9 en (4, 6) con costo 27
# Intentar asignar 7 en (4, 6) con costo 27
# Intentar asignar 9 en (4, 6) con costo 27
# Intentar asignar 7 en (4, 6) con costo 27
# Intentar asignar 7 en (4, 6) con costo 27
# Intentar asignar 7 en (4, 6) con costo 27
# Intentar asignar 9 en (4, 6) con costo 27
# Intentar asignar 7 en (4, 6) con costo 27
# Intentar asignar 9 en (4, 6) con costo 27
# Intentar asignar 7 en (4, 6) con costo 27
# Intentar asignar 7 en (4, 6) con costo 27
# Intentar asignar 9 en (4, 6) con costo 27
# Intentar asignar 7 en (4, 6) con costo 27
# Intentar asignar 7 en (4, 6) con costo 27
# Intentar asignar 9 en (4, 6) con costo 27
# Intentar asignar 7 en (4, 6) con costo 27
# Intentar asignar 7 en (4, 6) con costo 27
# Intentar asignar 9 en (4, 6) con costo 27
# Intentar asignar 7 en (4, 6) con costo 27
# Intentar asignar 9 en (4, 6) con costo 27
# Intentar asignar 7 en (4, 6) con costo 27
# Intentar asignar 7 en (4, 6) con costo 27
# Intentar asignar 9 en (4, 6) con costo 27
# Intentar asignar 7 en (4, 6) con costo 27
# Intentar asignar 7 en (4, 6) con costo 27
# Intentar asignar 9 en (4, 6) con costo 27
# Intentar asignar 7 en (4, 6) con costo 27
# Intentar asignar 7 en (4, 6) con costo 27
# Intentar asignar 9 en (4, 6) con costo 27
# Intentar asignar 7 en (4, 6) con costo 27
# Intentar asignar 9 en (4, 6) con costo 27
# Intentar asignar 7 en (4, 6) con costo 27
# Intentar asignar 7 en (4, 6) con costo 27
# Intentar asignar 7 en (4, 6) con costo 27
# Intentar asignar 9 en (4, 6) con costo 27
# Intentar asignar 7 en (4, 6) con costo 27
# Intentar asignar 9 en (4, 6) con costo 27
# Intentar asignar 7 en (4, 6) con costo 27
# Intentar asignar 7 en (4, 6) con costo 27
# Intentar asignar 9 en (4, 6) con costo 27
# Intentar asignar 7 en (4, 6) con costo 27
# Intentar asignar 7 en (4, 6) con costo 27
# Intentar asignar 7 en (4, 6) con costo 27
# Intentar asignar 7 en (4, 6) con costo 27
# Intentar asignar 7 en (4, 6) con costo 27
# Intentar asignar 7 en (4, 6) con costo 27
# Intentar asignar 7 en (4, 6) con costo 27
# Intentar asignar 7 en (4, 6) con costo 27
# Intentar asignar 7 en (4, 6) con costo 27
# Intentar asignar 7 en (4, 6) con costo 27
# Intentar asignar 7 en (4, 6) con costo 27
# Intentar asignar 7 en (4, 6) con costo 27
# Intentar asignar 7 en (4, 6) con costo 27
# Intentar asignar 7 en (4, 6) con costo 27
# Intentar asignar 7 en (4, 6) con costo 27
# Intentar asignar 7 en (4, 6) con costo 27
# Intentar asignar 7 en (4, 6) con costo 27
# Intentar asignar 7 en (4, 6) con costo 27
# Intentar asignar 7 en (4, 6) con costo 27
# Intentar asignar 7 en (4, 6) con costo 27
# Intentar asignar 9 en (4, 7) con costo 28
# Intentar asignar 9 en (4, 7) con costo 28
# Intentar asignar 9 en (4, 7) con costo 28
# Intentar asignar 9 en (4, 7) con costo 28
# Intentar asignar 9 en (4, 7) con costo 28
# Intentar asignar 9 en (4, 7) con costo 28
# Intentar asignar 9 en (4, 7) con costo 28
# Intentar asignar 9 en (4, 7) con costo 28
# Intentar asignar 9 en (4, 7) con costo 28
# Intentar asignar 9 en (4, 7) con costo 28
# Intentar asignar 9 en (4, 7) con costo 28
# Intentar asignar 9 en (4, 7) con costo 28
# Intentar asignar 9 en (4, 7) con costo 28
# Intentar asignar 9 en (4, 7) con costo 28
# Intentar asignar 9 en (4, 7) con costo 28
# Intentar asignar 9 en (4, 7) con costo 28
# Intentar asignar 9 en (4, 7) con costo 28
# Intentar asignar 9 en (4, 7) con costo 28
# Intentar asignar 9 en (4, 7) con costo 28
# Intentar asignar 9 en (4, 7) con costo 28
# Intentar asignar 9 en (4, 7) con costo 28
# Intentar asignar 9 en (4, 7) con costo 28
# Intentar asignar 9 en (4, 7) con costo 28
# Intentar asignar 9 en (4, 7) con costo 28
# Intentar asignar 1 en (5, 1) con costo 29
# Intentar asignar 1 en (5, 1) con costo 29
# Intentar asignar 1 en (5, 1) con costo 29
# Intentar asignar 1 en (5, 1) con costo 29
# Intentar asignar 1 en (5, 1) con costo 29
# Intentar asignar 1 en (5, 1) con costo 29
# Intentar asignar 1 en (5, 1) con costo 29
# Intentar asignar 1 en (5, 1) con costo 29
# Intentar asignar 3 en (5, 2) con costo 30
# Intentar asignar 3 en (5, 2) con costo 30
# Intentar asignar 3 en (5, 2) con costo 30
# Intentar asignar 3 en (5, 2) con costo 30
# Intentar asignar 3 en (5, 2) con costo 30
# Intentar asignar 3 en (5, 2) con costo 30
# Intentar asignar 3 en (5, 2) con costo 30
# Intentar asignar 3 en (5, 2) con costo 30
# Intentar asignar 9 en (5, 3) con costo 31
# Intentar asignar 9 en (5, 3) con costo 31
# Intentar asignar 9 en (5, 3) con costo 31
# Intentar asignar 9 en (5, 3) con costo 31
# Intentar asignar 9 en (5, 3) con costo 31
# Intentar asignar 9 en (5, 3) con costo 31
# Intentar asignar 9 en (5, 3) con costo 31
# Intentar asignar 9 en (5, 3) con costo 31
# Intentar asignar 4 en (5, 5) con costo 32
# Intentar asignar 4 en (5, 5) con costo 32
# Intentar asignar 4 en (5, 5) con costo 32
# Intentar asignar 4 en (5, 5) con costo 32
# Intentar asignar 8 en (5, 6) con costo 33
# Intentar asignar 5 en (5, 7) con costo 34
# Intentar asignar 3 en (6, 0) con costo 35
# Intentar asignar 9 en (6, 0) con costo 35
# Intentar asignar 1 en (6, 2) con costo 36
# Intentar asignar 5 en (6, 2) con costo 36
# Intentar asignar 7 en (6, 2) con costo 36
# Intentar asignar 1 en (6, 2) con costo 36
# Intentar asignar 5 en (6, 2) con costo 36
# Intentar asignar 7 en (6, 2) con costo 36
# Intentar asignar 5 en (6, 3) con costo 37
# Intentar asignar 5 en (6, 3) con costo 37
# Intentar asignar 5 en (6, 3) con costo 37
# Intentar asignar 5 en (6, 3) con costo 37
# Intentar asignar 3 en (6, 4) con costo 38
# Intentar asignar 3 en (6, 4) con costo 38
# Intentar asignar 7 en (6, 5) con costo 39
# Intentar asignar 4 en (6, 8) con costo 40
# Intentar asignar 2 en (7, 0) con costo 41
# Intentar asignar 3 en (7, 0) con costo 41
# Intentar asignar 8 en (7, 1) con costo 42
# Intentar asignar 8 en (7, 1) con costo 42
# Intentar asignar 7 en (7, 2) con costo 43
# Intentar asignar 7 en (7, 2) con costo 43
# Intentar asignar 6 en (7, 6) con costo 44
# Intentar asignar 6 en (7, 6) con costo 44
# Intentar asignar 3 en (7, 7) con costo 45
# Intentar asignar 3 en (8, 0) con costo 46
# Intentar asignar 4 en (8, 1) con costo 47
# Intentar asignar 5 en (8, 2) con costo 48
# Intentar asignar 2 en (8, 3) con costo 49
# Intentar asignar 6 en (8, 5) con costo 50
# Intentar asignar 1 en (8, 6) con costo 51
#
# Coste total de la solución:  51
# Sudoku Resuelto:
# 5 3 4 6 7 8 9 1 2
# 6 7 2 1 9 5 3 4 8
# 1 9 8 3 4 2 5 6 7
# 8 5 9 7 6 1 4 2 3
# 4 2 6 8 5 3 7 9 1
# 7 1 3 9 2 4 8 5 6
# 9 6 1 5 3 7 2 8 4
# 2 8 7 4 1 9 6 3 5
# 3 4 5 2 8 6 1 7 9
#
# ---------------------
